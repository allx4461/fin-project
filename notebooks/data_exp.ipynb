# %%
import yfinance as yf

nvda = yf.download("NVDA", start="2015-01-01", end="2024-01-01")
print(nvda.shape)
print(nvda.head())
nvda.to_parquet("../data/processed/nvda_prices.parquet")
